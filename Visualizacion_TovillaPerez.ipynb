# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # The information gather is related to the price stock of the three principal banks of USA and Mexico.
#
# # It is obtained by the same sources in datasets by bank.
#
# # For each dataset the 'Date' column is homologated to have the same data type.

# %% [markdown]
# ## J. P. Morgan

# %%
url_jpm = "https://raw.githubusercontent.com/danieltp92/Sources/main/JPM_Historical_Data.csv"
data_jpm = pd.read_csv(url_jpm)
data_jpm
# Out:
#            Date  Stock_Price_JPM(USD)  Open_Stock_Price_JPM(USD)  \
# 0     15-Jul-22                 19.96                      19.80
# 1     14-Jul-22                 19.20                      19.24
# 2     13-Jul-22                 19.69                      19.73
# 3     12-Jul-22                 19.73                      19.94
# 4     11-Jul-22                 19.94                      19.80
# ...         ...                   ...                        ...
# 1680   6-Nov-15                 31.43                      31.50
# 1681   5-Nov-15                 31.57                      31.40
# 1682   4-Nov-15                 31.05                      30.40
# 1683   3-Nov-15                 30.40                      30.29
# 1684  30-Oct-15                 30.35                      29.57
#
#       High_Stock_Price_JPM(USD)  Low_Stock_Price_JPM(USD) Vol_Stock_JPM  \
# 0                         19.96                     19.80        59.11K
# 1                         19.89                     19.18        52.36K
# 2                         19.73                     19.30         2.10K
# 3                         19.94                     19.20        50.46K
# 4                         19.96                     19.46        19.45K
# ...                         ...                       ...           ...
# 1680                      31.77                     31.06         3.43M
# 1681                      31.97                     31.21         5.91M
# 1682                      31.35                     30.36         6.19M
# 1683                      30.60                     29.81         7.59M
# 1684                      31.49                     29.40         7.49M
#
#      Change_Stock_JPM_Perc
# 0                    3.96%
# 1                   -2.49%
# 2                   -0.20%
# 3                   -1.05%
# 4                    0.00%
# ...                    ...
# 1680                -0.44%
# 1681                 1.67%
# 1682                 2.14%
# 1683                 0.16%
# 1684                 2.64%
#
# [1685 rows x 7 columns]

# %%
data_jpm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1685 entries, 0 to 1684
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       1685 non-null   object
#  1   Stock_Price_JPM(USD)       1685 non-null   float64
#  2   Open_Stock_Price_JPM(USD)  1685 non-null   float64
#  3   High_Stock_Price_JPM(USD)  1685 non-null   float64
#  4   Low_Stock_Price_JPM(USD)   1685 non-null   float64
#  5   Vol_Stock_JPM              1685 non-null   object
#  6   Change_Stock_JPM_Perc      1685 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 92.3+ KB

# %%
jpm_df = data_jpm.copy()
jpm_df['Date_time'] = jpm_df['Date'].astype('datetime64[ns]')
jpm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1685 entries, 0 to 1684
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       1685 non-null   object
#  1   Stock_Price_JPM(USD)       1685 non-null   float64
#  2   Open_Stock_Price_JPM(USD)  1685 non-null   float64
#  3   High_Stock_Price_JPM(USD)  1685 non-null   float64
#  4   Low_Stock_Price_JPM(USD)   1685 non-null   float64
#  5   Vol_Stock_JPM              1685 non-null   object
#  6   Change_Stock_JPM_Perc      1685 non-null   object
#  7   Date_time                  1685 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), object(3)
# memory usage: 105.4+ KB

# %%
columns_name = ["Date_time", "Stock_Price_JPM(USD)", "Open_Stock_Price_JPM(USD)", "High_Stock_Price_JPM(USD)", "Low_Stock_Price_JPM(USD)", "Vol_Stock_JPM", "Change_Stock_JPM_Perc"]
jpm_df = jpm_df.reindex(columns=columns_name)
jpm_df
# Out:
#       Date_time  Stock_Price_JPM(USD)  Open_Stock_Price_JPM(USD)  \
# 0    2022-07-15                 19.96                      19.80
# 1    2022-07-14                 19.20                      19.24
# 2    2022-07-13                 19.69                      19.73
# 3    2022-07-12                 19.73                      19.94
# 4    2022-07-11                 19.94                      19.80
# ...         ...                   ...                        ...
# 1680 2015-11-06                 31.43                      31.50
# 1681 2015-11-05                 31.57                      31.40
# 1682 2015-11-04                 31.05                      30.40
# 1683 2015-11-03                 30.40                      30.29
# 1684 2015-10-30                 30.35                      29.57
#
#       High_Stock_Price_JPM(USD)  Low_Stock_Price_JPM(USD) Vol_Stock_JPM  \
# 0                         19.96                     19.80        59.11K
# 1                         19.89                     19.18        52.36K
# 2                         19.73                     19.30         2.10K
# 3                         19.94                     19.20        50.46K
# 4                         19.96                     19.46        19.45K
# ...                         ...                       ...           ...
# 1680                      31.77                     31.06         3.43M
# 1681                      31.97                     31.21         5.91M
# 1682                      31.35                     30.36         6.19M
# 1683                      30.60                     29.81         7.59M
# 1684                      31.49                     29.40         7.49M
#
#      Change_Stock_JPM_Perc
# 0                    3.96%
# 1                   -2.49%
# 2                   -0.20%
# 3                   -1.05%
# 4                    0.00%
# ...                    ...
# 1680                -0.44%
# 1681                 1.67%
# 1682                 2.14%
# 1683                 0.16%
# 1684                 2.64%
#
# [1685 rows x 7 columns]

# %% [markdown]
# ## Bank of America

# %%
url_bac = "https://raw.githubusercontent.com/danieltp92/Sources/main/BAC_Historical_Data.csv"
data_bac = pd.read_csv(url_bac)
data_bac
# Out:
#            Date  Stock_Price_BAC(USD)  Open_Stock_Price_BAC(USD)  \
# 0     15-Jul-22                 32.38                      30.68
# 1     14-Jul-22                 30.13                      30.09
# 2     13-Jul-22                 30.84                      31.05
# 3     12-Jul-22                 31.36                      31.05
# 4     11-Jul-22                 31.46                      31.55
# ...         ...                   ...                        ...
# 2646   9-Jan-12                  6.27                       6.26
# 2647   6-Jan-12                  6.18                       6.21
# 2648   5-Jan-12                  6.31                       5.75
# 2649   4-Jan-12                  5.81                       5.71
# 2650   3-Jan-12                  5.80                       5.75
#
#       High_Stock_Price_BAC(USD)  Low_Stock_Price_BAC(USD) Vol_Stock_BAC  \
# 0                         32.40                     30.61        39.98M
# 1                         30.21                     29.68        51.20M
# 2                         31.13                     30.40        43.74M
# 3                         32.02                     30.99        39.34M
# 4                         31.79                     31.30        29.15M
# ...                         ...                       ...           ...
# 2646                       6.37                      6.19       240.61M
# 2647                       6.30                      6.06       299.63M
# 2648                       6.35                      5.71       547.78M
# 2649                       5.88                      5.62       243.71M
# 2650                       5.89                      5.74       246.29M
#
#      Change_Stock_BAC_Perc
# 0                    7.47%
# 1                   -2.30%
# 2                   -1.66%
# 3                   -0.32%
# 4                   -1.04%
# ...                    ...
# 2646                 1.46%
# 2647                -2.06%
# 2648                 8.61%
# 2649                 0.17%
# 2650                 4.32%
#
# [2651 rows x 7 columns]

# %%
data_bac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2651 entries, 0 to 2650
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       2651 non-null   object
#  1   Stock_Price_BAC(USD)       2651 non-null   float64
#  2   Open_Stock_Price_BAC(USD)  2651 non-null   float64
#  3   High_Stock_Price_BAC(USD)  2651 non-null   float64
#  4   Low_Stock_Price_BAC(USD)   2651 non-null   float64
#  5   Vol_Stock_BAC              2651 non-null   object
#  6   Change_Stock_BAC_Perc      2651 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 145.1+ KB

# %%
bac_df = data_bac.copy()
bac_df['Date_time'] = bac_df['Date'].astype('datetime64[ns]')
bac_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2651 entries, 0 to 2650
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       2651 non-null   object
#  1   Stock_Price_BAC(USD)       2651 non-null   float64
#  2   Open_Stock_Price_BAC(USD)  2651 non-null   float64
#  3   High_Stock_Price_BAC(USD)  2651 non-null   float64
#  4   Low_Stock_Price_BAC(USD)   2651 non-null   float64
#  5   Vol_Stock_BAC              2651 non-null   object
#  6   Change_Stock_BAC_Perc      2651 non-null   object
#  7   Date_time                  2651 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), object(3)
# memory usage: 165.8+ KB

# %%
columns_name = ["Date_time", "Stock_Price_BAC(USD)", "Open_Stock_Price_BAC(USD)", "High_Stock_Price_BAC(USD)", "Low_Stock_Price_BAC(USD)", "Vol_Stock_BAC", "Change_Stock_BAC_Perc"]
bac_df = bac_df.reindex(columns=columns_name)
bac_df
# Out:
#       Date_time  Stock_Price_BAC(USD)  Open_Stock_Price_BAC(USD)  \
# 0    2022-07-15                 32.38                      30.68
# 1    2022-07-14                 30.13                      30.09
# 2    2022-07-13                 30.84                      31.05
# 3    2022-07-12                 31.36                      31.05
# 4    2022-07-11                 31.46                      31.55
# ...         ...                   ...                        ...
# 2646 2012-01-09                  6.27                       6.26
# 2647 2012-01-06                  6.18                       6.21
# 2648 2012-01-05                  6.31                       5.75
# 2649 2012-01-04                  5.81                       5.71
# 2650 2012-01-03                  5.80                       5.75
#
#       High_Stock_Price_BAC(USD)  Low_Stock_Price_BAC(USD) Vol_Stock_BAC  \
# 0                         32.40                     30.61        39.98M
# 1                         30.21                     29.68        51.20M
# 2                         31.13                     30.40        43.74M
# 3                         32.02                     30.99        39.34M
# 4                         31.79                     31.30        29.15M
# ...                         ...                       ...           ...
# 2646                       6.37                      6.19       240.61M
# 2647                       6.30                      6.06       299.63M
# 2648                       6.35                      5.71       547.78M
# 2649                       5.88                      5.62       243.71M
# 2650                       5.89                      5.74       246.29M
#
#      Change_Stock_BAC_Perc
# 0                    7.47%
# 1                   -2.30%
# 2                   -1.66%
# 3                   -0.32%
# 4                   -1.04%
# ...                    ...
# 2646                 1.46%
# 2647                -2.06%
# 2648                 8.61%
# 2649                 0.17%
# 2650                 4.32%
#
# [2651 rows x 7 columns]

# %% [markdown]
# ## Wells Fargo

# %%
url_wfc = "https://raw.githubusercontent.com/danieltp92/Sources/main/WFC_Historical_Data.csv"
data_wfc = pd.read_csv(url_wfc)
data_wfc
# Out:
#            Date  Stock_Price_WFC(USD)  Open_Stock_Price_WFC(USD)  \
# 0     15-Jul-22                 41.24                      40.04
# 1     14-Jul-22                 38.74                      38.05
# 2     13-Jul-22                 39.07                      39.09
# 3     12-Jul-22                 39.60                      39.06
# 4     11-Jul-22                 39.79                      39.67
# ...         ...                   ...                        ...
# 2646   9-Jan-12                 29.30                      29.15
# 2647   6-Jan-12                 28.94                      28.84
# 2648   5-Jan-12                 29.02                      28.50
# 2649   4-Jan-12                 28.56                      28.34
# 2650   3-Jan-12                 28.43                      27.94
#
#       High_Stock_Price_WFC(USD)  Low_Stock_Price_WFC(USD) Vol_Stock_WFC  \
# 0                         41.80                     39.30        24.01M
# 1                         38.75                     37.45        24.29M
# 2                         39.35                     38.41        14.06M
# 3                         40.47                     39.05        14.87M
# 4                         40.01                     39.24        13.10M
# ...                         ...                       ...           ...
# 2646                      29.38                     29.00        25.73M
# 2647                      29.08                     28.46        32.30M
# 2648                      29.58                     28.25        48.44M
# 2649                      28.69                     28.04        27.52M
# 2650                      28.52                     27.94        40.07M
#
#      Change_Stock_WFC_Perc
# 0                    6.45%
# 1                   -0.84%
# 2                   -1.34%
# 3                   -0.48%
# 4                   -0.97%
# ...                    ...
# 2646                 1.24%
# 2647                -0.28%
# 2648                 1.61%
# 2649                 0.46%
# 2650                 3.16%
#
# [2651 rows x 7 columns]

# %%
data_wfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2651 entries, 0 to 2650
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       2651 non-null   object
#  1   Stock_Price_WFC(USD)       2651 non-null   float64
#  2   Open_Stock_Price_WFC(USD)  2651 non-null   float64
#  3   High_Stock_Price_WFC(USD)  2651 non-null   float64
#  4   Low_Stock_Price_WFC(USD)   2651 non-null   float64
#  5   Vol_Stock_WFC              2651 non-null   object
#  6   Change_Stock_WFC_Perc      2651 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 145.1+ KB

# %%
wfc_df = data_wfc.copy()
wfc_df['Date_time'] = wfc_df['Date'].astype('datetime64[ns]')
wfc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2651 entries, 0 to 2650
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       2651 non-null   object
#  1   Stock_Price_WFC(USD)       2651 non-null   float64
#  2   Open_Stock_Price_WFC(USD)  2651 non-null   float64
#  3   High_Stock_Price_WFC(USD)  2651 non-null   float64
#  4   Low_Stock_Price_WFC(USD)   2651 non-null   float64
#  5   Vol_Stock_WFC              2651 non-null   object
#  6   Change_Stock_WFC_Perc      2651 non-null   object
#  7   Date_time                  2651 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), object(3)
# memory usage: 165.8+ KB

# %%
columns_name = ["Date_time", "Stock_Price_WFC(USD)", "Open_Stock_Price_WFC(USD)", "High_Stock_Price_WFC(USD)", "Low_Stock_Price_WFC(USD)", "Vol_Stock_WFC", "Change_Stock_WFC_Perc"]
wfc_df = wfc_df.reindex(columns=columns_name)
wfc_df
# Out:
#       Date_time  Stock_Price_WFC(USD)  Open_Stock_Price_WFC(USD)  \
# 0    2022-07-15                 41.24                      40.04
# 1    2022-07-14                 38.74                      38.05
# 2    2022-07-13                 39.07                      39.09
# 3    2022-07-12                 39.60                      39.06
# 4    2022-07-11                 39.79                      39.67
# ...         ...                   ...                        ...
# 2646 2012-01-09                 29.30                      29.15
# 2647 2012-01-06                 28.94                      28.84
# 2648 2012-01-05                 29.02                      28.50
# 2649 2012-01-04                 28.56                      28.34
# 2650 2012-01-03                 28.43                      27.94
#
#       High_Stock_Price_WFC(USD)  Low_Stock_Price_WFC(USD) Vol_Stock_WFC  \
# 0                         41.80                     39.30        24.01M
# 1                         38.75                     37.45        24.29M
# 2                         39.35                     38.41        14.06M
# 3                         40.47                     39.05        14.87M
# 4                         40.01                     39.24        13.10M
# ...                         ...                       ...           ...
# 2646                      29.38                     29.00        25.73M
# 2647                      29.08                     28.46        32.30M
# 2648                      29.58                     28.25        48.44M
# 2649                      28.69                     28.04        27.52M
# 2650                      28.52                     27.94        40.07M
#
#      Change_Stock_WFC_Perc
# 0                    6.45%
# 1                   -0.84%
# 2                   -1.34%
# 3                   -0.48%
# 4                   -0.97%
# ...                    ...
# 2646                 1.24%
# 2647                -0.28%
# 2648                 1.61%
# 2649                 0.46%
# 2650                 3.16%
#
# [2651 rows x 7 columns]

# %% [markdown]
# ## BBVA Bancomer

# %%
url_bbva = "https://raw.githubusercontent.com/danieltp92/Sources/main/BBVA_Historical_Data.csv"
data_bbva = pd.read_csv(url_bbva)
data_bbva
# Out:
#            Date  Stock_Price_BBVA(MXN)  Open_Stock_Price_BBVA(MXN)  \
# 0     15-Jul-22                92.8330                     92.8330
# 1     14-Jul-22                94.1395                     94.1395
# 2     13-Jul-22                94.3954                     94.3954
# 3     12-Jul-22                94.1151                     94.1151
# 4     11-Jul-22                94.6610                     94.6610
# ...         ...                    ...                         ...
# 2187  14-May-13                88.6344                     88.6344
# 2188  13-May-13                88.5712                     88.5712
# 2189  10-May-13                88.4794                     88.4794
# 2190   9-May-13                89.3527                     89.3527
# 2191   8-May-13                89.9413                     89.9413
#
#       High_Stock_Price_BBVA(MXN)  Low_Stock_Price_BBVA(MXN) Vol_Stock_BBVA  \
# 0                        92.8330                    92.8330              -
# 1                        94.1395                    94.1395              -
# 2                        94.3954                    94.3954              -
# 3                        94.1151                    94.1151              -
# 4                        94.6610                    94.6610              -
# ...                          ...                        ...            ...
# 2187                     88.6344                    88.6344          0.00K
# 2188                     88.5712                    88.5712          0.00K
# 2189                     88.4794                    88.4794          0.00K
# 2190                     89.3527                    89.3527          0.00K
# 2191                     89.9413                    89.9413          0.00K
#
#      Change_Stock_BBVA_Perc
# 0                    -1.39%
# 1                    -0.27%
# 2                     0.30%
# 3                    -0.58%
# 4                     0.27%
# ...                     ...
# 2187                  0.07%
# 2188                  0.10%
# 2189                 -0.98%
# 2190                 -0.65%
# 2191                  0.46%
#
# [2192 rows x 7 columns]

# %%
data_bbva.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2192 entries, 0 to 2191
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        2192 non-null   object
#  1   Stock_Price_BBVA(MXN)       2192 non-null   float64
#  2   Open_Stock_Price_BBVA(MXN)  2192 non-null   float64
#  3   High_Stock_Price_BBVA(MXN)  2192 non-null   float64
#  4   Low_Stock_Price_BBVA(MXN)   2192 non-null   float64
#  5   Vol_Stock_BBVA              2192 non-null   object
#  6   Change_Stock_BBVA_Perc      2192 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 120.0+ KB

# %%
bbva_df = data_bbva.copy()
bbva_df['Date_time'] = bbva_df['Date'].astype('datetime64[ns]')
bbva_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2192 entries, 0 to 2191
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        2192 non-null   object
#  1   Stock_Price_BBVA(MXN)       2192 non-null   float64
#  2   Open_Stock_Price_BBVA(MXN)  2192 non-null   float64
#  3   High_Stock_Price_BBVA(MXN)  2192 non-null   float64
#  4   Low_Stock_Price_BBVA(MXN)   2192 non-null   float64
#  5   Vol_Stock_BBVA              2192 non-null   object
#  6   Change_Stock_BBVA_Perc      2192 non-null   object
#  7   Date_time                   2192 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), object(3)
# memory usage: 137.1+ KB

# %%
columns_name = ["Date_time", "Stock_Price_BBVA(MXN)", "Open_Stock_Price_BBVA(MXN)", "High_Stock_Price_BBVA(MXN)", "Low_Stock_Price_BBVA(MXN)", "Vol_Stock_BBVA", "Change_Stock_BBVA_Perc"]
bbva_df = bbva_df.reindex(columns=columns_name)
bbva_df
# Out:
#       Date_time  Stock_Price_BBVA(MXN)  Open_Stock_Price_BBVA(MXN)  \
# 0    2022-07-15                92.8330                     92.8330
# 1    2022-07-14                94.1395                     94.1395
# 2    2022-07-13                94.3954                     94.3954
# 3    2022-07-12                94.1151                     94.1151
# 4    2022-07-11                94.6610                     94.6610
# ...         ...                    ...                         ...
# 2187 2013-05-14                88.6344                     88.6344
# 2188 2013-05-13                88.5712                     88.5712
# 2189 2013-05-10                88.4794                     88.4794
# 2190 2013-05-09                89.3527                     89.3527
# 2191 2013-05-08                89.9413                     89.9413
#
#       High_Stock_Price_BBVA(MXN)  Low_Stock_Price_BBVA(MXN) Vol_Stock_BBVA  \
# 0                        92.8330                    92.8330              -
# 1                        94.1395                    94.1395              -
# 2                        94.3954                    94.3954              -
# 3                        94.1151                    94.1151              -
# 4                        94.6610                    94.6610              -
# ...                          ...                        ...            ...
# 2187                     88.6344                    88.6344          0.00K
# 2188                     88.5712                    88.5712          0.00K
# 2189                     88.4794                    88.4794          0.00K
# 2190                     89.3527                    89.3527          0.00K
# 2191                     89.9413                    89.9413          0.00K
#
#      Change_Stock_BBVA_Perc
# 0                    -1.39%
# 1                    -0.27%
# 2                     0.30%
# 3                    -0.58%
# 4                     0.27%
# ...                     ...
# 2187                  0.07%
# 2188                  0.10%
# 2189                 -0.98%
# 2190                 -0.65%
# 2191                  0.46%
#
# [2192 rows x 7 columns]

# %% [markdown]
# ## Santander Mexico

# %%
url_sant = "https://raw.githubusercontent.com/danieltp92/Sources/main/SantMx_Historical_Data.csv"
data_sant = pd.read_csv(url_sant)
data_sant
# Out:
#            Date  Stock_Price_SantMx(MXN)  Open_Stock_Price_SantMx(MXN)  \
# 0     15-Jul-22                    20.00                         19.80
# 1     14-Jul-22                    19.20                         19.24
# 2     13-Jul-22                    19.69                         19.73
# 3     12-Jul-22                    19.73                         19.94
# 4     11-Jul-22                    19.94                         19.80
# ...         ...                      ...                           ...
# 1680   6-Nov-15                    31.43                         31.50
# 1681   5-Nov-15                    31.57                         31.40
# 1682   4-Nov-15                    31.05                         30.40
# 1683   3-Nov-15                    30.40                         30.29
# 1684  30-Oct-15                    30.35                         29.57
#
#       High_Stock_Price_SantMx(MXN)  Low_Stock_Price_SantMx(MXN)  \
# 0                            20.12                        19.80
# 1                            19.89                        19.18
# 2                            19.73                        19.30
# 3                            19.94                        19.20
# 4                            19.96                        19.46
# ...                            ...                          ...
# 1680                         31.77                        31.06
# 1681                         31.97                        31.21
# 1682                         31.35                        30.36
# 1683                         30.60                        29.81
# 1684                         31.49                        29.40
#
#      Vol_Stock_SantMx Change_Stock_SantMx_Perc
# 0             156.35K                    4.17%
# 1              52.36K                   -2.49%
# 2               2.10K                   -0.20%
# 3              50.46K                   -1.05%
# 4              19.45K                    0.00%
# ...               ...                      ...
# 1680            3.43M                   -0.44%
# 1681            5.91M                    1.67%
# 1682            6.19M                    2.14%
# 1683            7.59M                    0.16%
# 1684            7.49M                    2.64%
#
# [1685 rows x 7 columns]

# %%
data_sant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1685 entries, 0 to 1684
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date                          1685 non-null   object
#  1   Stock_Price_SantMx(MXN)       1685 non-null   float64
#  2   Open_Stock_Price_SantMx(MXN)  1685 non-null   float64
#  3   High_Stock_Price_SantMx(MXN)  1685 non-null   float64
#  4   Low_Stock_Price_SantMx(MXN)   1685 non-null   float64
#  5   Vol_Stock_SantMx              1685 non-null   object
#  6   Change_Stock_SantMx_Perc      1685 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 92.3+ KB

# %%
sant_df = data_sant.copy()
sant_df['Date_time'] = sant_df['Date'].astype('datetime64[ns]')
sant_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1685 entries, 0 to 1684
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date                          1685 non-null   object
#  1   Stock_Price_SantMx(MXN)       1685 non-null   float64
#  2   Open_Stock_Price_SantMx(MXN)  1685 non-null   float64
#  3   High_Stock_Price_SantMx(MXN)  1685 non-null   float64
#  4   Low_Stock_Price_SantMx(MXN)   1685 non-null   float64
#  5   Vol_Stock_SantMx              1685 non-null   object
#  6   Change_Stock_SantMx_Perc      1685 non-null   object
#  7   Date_time                     1685 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), object(3)
# memory usage: 105.4+ KB

# %%
columns_name = ["Date_time", "Stock_Price_SantMx(MXN)", "Open_Stock_Price_SantMx(MXN)", "High_Stock_Price_SantMx(MXN)", "Low_Stock_Price_SantMx(MXN)", "Vol_Stock_SantMx", "Change_Stock_SantMx_Perc"]
sant_df = sant_df.reindex(columns=columns_name)
sant_df
# Out:
#       Date_time  Stock_Price_SantMx(MXN)  Open_Stock_Price_SantMx(MXN)  \
# 0    2022-07-15                    20.00                         19.80
# 1    2022-07-14                    19.20                         19.24
# 2    2022-07-13                    19.69                         19.73
# 3    2022-07-12                    19.73                         19.94
# 4    2022-07-11                    19.94                         19.80
# ...         ...                      ...                           ...
# 1680 2015-11-06                    31.43                         31.50
# 1681 2015-11-05                    31.57                         31.40
# 1682 2015-11-04                    31.05                         30.40
# 1683 2015-11-03                    30.40                         30.29
# 1684 2015-10-30                    30.35                         29.57
#
#       High_Stock_Price_SantMx(MXN)  Low_Stock_Price_SantMx(MXN)  \
# 0                            20.12                        19.80
# 1                            19.89                        19.18
# 2                            19.73                        19.30
# 3                            19.94                        19.20
# 4                            19.96                        19.46
# ...                            ...                          ...
# 1680                         31.77                        31.06
# 1681                         31.97                        31.21
# 1682                         31.35                        30.36
# 1683                         30.60                        29.81
# 1684                         31.49                        29.40
#
#      Vol_Stock_SantMx Change_Stock_SantMx_Perc
# 0             156.35K                    4.17%
# 1              52.36K                   -2.49%
# 2               2.10K                   -0.20%
# 3              50.46K                   -1.05%
# 4              19.45K                    0.00%
# ...               ...                      ...
# 1680            3.43M                   -0.44%
# 1681            5.91M                    1.67%
# 1682            6.19M                    2.14%
# 1683            7.59M                    0.16%
# 1684            7.49M                    2.64%
#
# [1685 rows x 7 columns]

# %% [markdown]
# ## Banorte Mexico

# %%
url_bano = "https://raw.githubusercontent.com/danieltp92/Sources/main/BanorteMx_Historical_Data.csv"
data_bano = pd.read_csv(url_bano)
data_bano
# Out:
#            Date  Stock_Price_BanorteMx(MXN)  Open_Stock_Price_BanorteMx(MXN)  \
# 0     15-Jul-22                      113.25                           113.99
# 1     14-Jul-22                      113.54                           114.01
# 2     13-Jul-22                      114.96                           114.51
# 3     12-Jul-22                      115.05                           111.64
# 4     11-Jul-22                      111.57                           113.00
# ...         ...                         ...                              ...
# 2646   6-Jan-12                       44.72                            44.05
# 2647   5-Jan-12                       44.00                            43.66
# 2648   4-Jan-12                       43.49                            43.32
# 2649   3-Jan-12                       43.44                            43.25
# 2650   2-Jan-12                       42.95                            43.20
#
#       High_Stock_Price_BanorteMx(MXN)  Low_Stock_Price_BanorteMx(MXN)  \
# 0                              114.53                          112.83
# 1                              114.34                          112.91
# 2                              117.21                          114.51
# 3                              115.68                          110.62
# 4                              113.00                          111.14
# ...                               ...                             ...
# 2646                            45.00                           44.01
# 2647                            44.60                           42.90
# 2648                            43.88                           42.56
# 2649                            43.82                           43.16
# 2650                            43.20                           42.40
#
#      Vol_Stock_BanorteMx Change_Stock_BanorteMx_Perc
# 0                  2.78M                      -0.26%
# 1                  6.47M                      -1.24%
# 2                  7.57M                      -0.08%
# 3                  8.89M                       3.12%
# 4                  6.54M                      -1.90%
# ...                  ...                         ...
# 2646               2.79M                       1.64%
# 2647               7.99M                       1.17%
# 2648               2.12M                       0.12%
# 2649               1.87M                       1.14%
# 2650             236.00K                       1.49%
#
# [2651 rows x 7 columns]

# %%
data_bano.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2651 entries, 0 to 2650
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date                             2651 non-null   object
#  1   Stock_Price_BanorteMx(MXN)       2651 non-null   float64
#  2   Open_Stock_Price_BanorteMx(MXN)  2651 non-null   float64
#  3   High_Stock_Price_BanorteMx(MXN)  2651 non-null   float64
#  4   Low_Stock_Price_BanorteMx(MXN)   2651 non-null   float64
#  5   Vol_Stock_BanorteMx              2651 non-null   object
#  6   Change_Stock_BanorteMx_Perc      2651 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 145.1+ KB

# %%
bano_df = data_bano.copy()
bano_df['Date_time'] = bano_df['Date'].astype('datetime64[ns]')
bano_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2651 entries, 0 to 2650
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date                             2651 non-null   object
#  1   Stock_Price_BanorteMx(MXN)       2651 non-null   float64
#  2   Open_Stock_Price_BanorteMx(MXN)  2651 non-null   float64
#  3   High_Stock_Price_BanorteMx(MXN)  2651 non-null   float64
#  4   Low_Stock_Price_BanorteMx(MXN)   2651 non-null   float64
#  5   Vol_Stock_BanorteMx              2651 non-null   object
#  6   Change_Stock_BanorteMx_Perc      2651 non-null   object
#  7   Date_time                        2651 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), object(3)
# memory usage: 165.8+ KB

# %%
columns_name = ["Date_time", "Stock_Price_BanorteMx(MXN)", "Open_Stock_Price_BanorteMx(MXN)", "High_Stock_Price_BanorteMx(MXN)", "Low_Stock_Price_BanorteMx(MXN)", "Vol_Stock_BanorteMx", "Change_Stock_BanorteMx_Perc"]
bano_df = bano_df.reindex(columns=columns_name)
bano_df
# Out:
#       Date_time  Stock_Price_BanorteMx(MXN)  Open_Stock_Price_BanorteMx(MXN)  \
# 0    2022-07-15                      113.25                           113.99
# 1    2022-07-14                      113.54                           114.01
# 2    2022-07-13                      114.96                           114.51
# 3    2022-07-12                      115.05                           111.64
# 4    2022-07-11                      111.57                           113.00
# ...         ...                         ...                              ...
# 2646 2012-01-06                       44.72                            44.05
# 2647 2012-01-05                       44.00                            43.66
# 2648 2012-01-04                       43.49                            43.32
# 2649 2012-01-03                       43.44                            43.25
# 2650 2012-01-02                       42.95                            43.20
#
#       High_Stock_Price_BanorteMx(MXN)  Low_Stock_Price_BanorteMx(MXN)  \
# 0                              114.53                          112.83
# 1                              114.34                          112.91
# 2                              117.21                          114.51
# 3                              115.68                          110.62
# 4                              113.00                          111.14
# ...                               ...                             ...
# 2646                            45.00                           44.01
# 2647                            44.60                           42.90
# 2648                            43.88                           42.56
# 2649                            43.82                           43.16
# 2650                            43.20                           42.40
#
#      Vol_Stock_BanorteMx Change_Stock_BanorteMx_Perc
# 0                  2.78M                      -0.26%
# 1                  6.47M                      -1.24%
# 2                  7.57M                      -0.08%
# 3                  8.89M                       3.12%
# 4                  6.54M                      -1.90%
# ...                  ...                         ...
# 2646               2.79M                       1.64%
# 2647               7.99M                       1.17%
# 2648               2.12M                       0.12%
# 2649               1.87M                       1.14%
# 2650             236.00K                       1.49%
#
# [2651 rows x 7 columns]

# %% [markdown]
# # The information is joined in one final dataset which is going to be used as the master data

# %%
df_banks = pd.merge(jpm_df, bac_df, how='outer', on='Date_time')
df_banks = pd.merge(df_banks, wfc_df, how='outer', on='Date_time')
df_banks = pd.merge(df_banks, bbva_df, how='outer', on='Date_time')
df_banks = pd.merge(df_banks, sant_df, how='outer', on='Date_time')
df_banks = pd.merge(df_banks, bano_df, how='outer', on='Date_time')
df_banks
# Out:
#       Date_time  Stock_Price_JPM(USD)  Open_Stock_Price_JPM(USD)  \
# 0    2022-07-15                 19.96                      19.80
# 1    2022-07-14                 19.20                      19.24
# 2    2022-07-13                 19.69                      19.73
# 3    2022-07-12                 19.73                      19.94
# 4    2022-07-11                 19.94                      19.80
# ...         ...                   ...                        ...
# 2718 2012-07-04                   NaN                        NaN
# 2719 2012-05-28                   NaN                        NaN
# 2720 2012-02-20                   NaN                        NaN
# 2721 2012-01-16                   NaN                        NaN
# 2722 2012-01-02                   NaN                        NaN
#
#       High_Stock_Price_JPM(USD)  Low_Stock_Price_JPM(USD) Vol_Stock_JPM  \
# 0                         19.96                     19.80        59.11K
# 1                         19.89                     19.18        52.36K
# 2                         19.73                     19.30         2.10K
# 3                         19.94                     19.20        50.46K
# 4                         19.96                     19.46        19.45K
# ...                         ...                       ...           ...
# 2718                        NaN                       NaN           NaN
# 2719                        NaN                       NaN           NaN
# 2720                        NaN                       NaN           NaN
# 2721                        NaN                       NaN           NaN
# 2722                        NaN                       NaN           NaN
#
#      Change_Stock_JPM_Perc  Stock_Price_BAC(USD)  Open_Stock_Price_BAC(USD)  \
# 0                    3.96%                 32.38                      30.68
# 1                   -2.49%                 30.13                      30.09
# 2                   -0.20%                 30.84                      31.05
# 3                   -1.05%                 31.36                      31.05
# 4                    0.00%                 31.46                      31.55
# ...                    ...                   ...                        ...
# 2718                   NaN                   NaN                        NaN
# 2719                   NaN                   NaN                        NaN
# 2720                   NaN                   NaN                        NaN
# 2721                   NaN                   NaN                        NaN
# 2722                   NaN                   NaN                        NaN
#
#       High_Stock_Price_BAC(USD)  ...  High_Stock_Price_SantMx(MXN)  \
# 0                         32.40  ...                         20.12
# 1                         30.21  ...                         19.89
# 2                         31.13  ...                         19.73
# 3                         32.02  ...                         19.94
# 4                         31.79  ...                         19.96
# ...                         ...  ...                           ...
# 2718                        NaN  ...                           NaN
# 2719                        NaN  ...                           NaN
# 2720                        NaN  ...                           NaN
# 2721                        NaN  ...                           NaN
# 2722                        NaN  ...                           NaN
#
#      Low_Stock_Price_SantMx(MXN) Vol_Stock_SantMx  Change_Stock_SantMx_Perc  \
# 0                          19.80          156.35K                     4.17%
# 1                          19.18           52.36K                    -2.49%
# 2                          19.30            2.10K                    -0.20%
# 3                          19.20           50.46K                    -1.05%
# 4                          19.46           19.45K                     0.00%
# ...                          ...              ...                       ...
# 2718                         NaN              NaN                       NaN
# 2719                         NaN              NaN                       NaN
# 2720                         NaN              NaN                       NaN
# 2721                         NaN              NaN                       NaN
# 2722                         NaN              NaN                       NaN
#
#       Stock_Price_BanorteMx(MXN)  Open_Stock_Price_BanorteMx(MXN)  \
# 0                         113.25                           113.99
# 1                         113.54                           114.01
# 2                         114.96                           114.51
# 3                         115.05                           111.64
# 4                         111.57                           113.00
# ...                          ...                              ...
# 2718                       68.07                            68.92
# 2719                       59.92                            58.52
# 2720                       54.00                            52.52
# 2721                       48.14                            48.19
# 2722                       42.95                            43.20
#
#       High_Stock_Price_BanorteMx(MXN) Low_Stock_Price_BanorteMx(MXN)  \
# 0                              114.53                         112.83
# 1                              114.34                         112.91
# 2                              117.21                         114.51
# 3                              115.68                         110.62
# 4                              113.00                         111.14
# ...                               ...                            ...
# 2718                            69.33                          68.01
# 2719                            60.26                          58.52
# 2720                            54.20                          52.51
# 2721                            48.25                          47.85
# 2722                            43.20                          42.40
#
#      Vol_Stock_BanorteMx  Change_Stock_BanorteMx_Perc
# 0                  2.78M                       -0.26%
# 1                  6.47M                       -1.24%
# 2                  7.57M                       -0.08%
# 3                  8.89M                        3.12%
# 4                  6.54M                       -1.90%
# ...                  ...                          ...
# 2718             804.09K                       -1.23%
# 2719             859.74K                        0.72%
# 2720               1.57M                        0.97%
# 2721               4.43M                        0.52%
# 2722             236.00K                        1.49%
#
# [2723 rows x 37 columns]

# %%
df_banks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2723 entries, 0 to 2722
# Data columns (total 37 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date_time                        2723 non-null   datetime64[ns]
#  1   Stock_Price_JPM(USD)             1685 non-null   float64
#  2   Open_Stock_Price_JPM(USD)        1685 non-null   float64
#  3   High_Stock_Price_JPM(USD)        1685 non-null   float64
#  4   Low_Stock_Price_JPM(USD)         1685 non-null   float64
#  5   Vol_Stock_JPM                    1685 non-null   object
#  6   Change_Stock_JPM_Perc            1685 non-null   object
#  7   Stock_Price_BAC(USD)             2651 non-null   float64
#  8   Open_Stock_Price_BAC(USD)        2651 non-null   float64
#  9   High_Stock_Price_BAC(USD)        2651 non-null   float64
#  10  Low_Stock_Price_BAC(USD)         2651 non-null   float64
#  11  Vol_Stock_BAC                    2651 non-null   object
#  12  Change_Stock_BAC_Perc            2651 non-null   object
#  13  Stock_Price_WFC(USD)             2651 non-null   float64
#  14  Open_Stock_Price_WFC(USD)        2651 non-null   float64
#  15  High_Stock_Price_WFC(USD)        2651 non-null   float64
#  16  Low_Stock_Price_WFC(USD)         2651 non-null   float64
#  17  Vol_Stock_WFC                    2651 non-null   object
#  18  Change_Stock_WFC_Perc            2651 non-null   object
#  19  Stock_Price_BBVA(MXN)            2192 non-null   float64
#  20  Open_Stock_Price_BBVA(MXN)       2192 non-null   float64
#  21  High_Stock_Price_BBVA(MXN)       2192 non-null   float64
#  22  Low_Stock_Price_BBVA(MXN)        2192 non-null   float64
#  23  Vol_Stock_BBVA                   2192 non-null   object
#  24  Change_Stock_BBVA_Perc           2192 non-null   object
#  25  Stock_Price_SantMx(MXN)          1685 non-null   float64
#  26  Open_Stock_Price_SantMx(MXN)     1685 non-null   float64
#  27  High_Stock_Price_SantMx(MXN)     1685 non-null   float64
#  28  Low_Stock_Price_SantMx(MXN)      1685 non-null   float64
#  29  Vol_Stock_SantMx                 1685 non-null   object
#  30  Change_Stock_SantMx_Perc         1685 non-null   object
#  31  Stock_Price_BanorteMx(MXN)       2651 non-null   float64
#  32  Open_Stock_Price_BanorteMx(MXN)  2651 non-null   float64
#  33  High_Stock_Price_BanorteMx(MXN)  2651 non-null   float64
#  34  Low_Stock_Price_BanorteMx(MXN)   2651 non-null   float64
#  35  Vol_Stock_BanorteMx              2651 non-null   object
#  36  Change_Stock_BanorteMx_Perc      2651 non-null   object
# dtypes: datetime64[ns](1), float64(24), object(12)
# memory usage: 808.4+ KB

# %% [markdown]
# # Once the data is in one dataset, a comparison between banks in USA is made to watch their stock behavior during the time.

# %%
plt.plot(df_banks['Date_time'], df_banks['Stock_Price_JPM(USD)'], label='J. P. Morgan')
plt.plot(df_banks['Date_time'], df_banks['Stock_Price_BAC(USD)'], label='Bank of America')
plt.plot(df_banks['Date_time'], df_banks['Stock_Price_WFC(USD)'], label='Wells Fargo')
plt.legend(loc='upper left')

# %% [markdown]
# # The behavior of Wells Fargo is better than the other two, although Bank of America has been increasing their stock value during the pass of the time, having lower value lost.

# %%
df_banks.plot(x="Date_time", y=["Open_Stock_Price_JPM(USD)", "High_Stock_Price_JPM(USD)", "Low_Stock_Price_JPM(USD)"], kind="bar")
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # The compare between the Stock prices during the time, while the market open, when hits ther higher and lower value and the final stock value is difficult to track for the volume of the data.

# %%
plt.scatter(df_banks['Date_time'], df_banks['Open_Stock_Price_JPM(USD)'], label='J.P.M. Open Stock')
plt.scatter(df_banks['Date_time'], df_banks['Stock_Price_JPM(USD)'], label='J.P.M. Stock')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# # In the scatter plot you can observe that the value when the Market is open and the final value of the day, has not much variance, showing that the price is consistent during the day. But in the pass of the time, you can observe that the Stock value has some depresiation.

# %%
sns.barplot(x=df_banks['Date_time'], y=df_banks['Low_Stock_Price_BBVA(MXN)'])

# %% [markdown]
# # The bar plot graph above show the behavior of the value of BBVA in Mexico, showing that when it starts and today has a bigger improvement.

# %% [markdown]
# # However, below with the box plot graphs, we analyze the value of the stocks and see that BBVA has a lot of outliers in their values, different from Banorte and Santader. This leads to think that the information may not be consistent, or they have big drops in their stock values refelcting a higher risk for investment.

# %%
sns.boxplot(x=df_banks["Stock_Price_BBVA(MXN)"])

# %%
sns.boxplot(x=df_banks["Stock_Price_BanorteMx(MXN)"], showfliers="True")

# %%
sns.boxplot(x=df_banks["Stock_Price_SantMx(MXN)"])
